# %%
import pandas as pd 
from pandas import DataFrame
#이를 통해 더이상 pd.DataFrame 으로 생성할 필요가 없다! 


data = DataFrame(
data=[['서울',12000,15000],    ['경기',75000,18000],     ['제주',63000,66000] , ['부산',42000,50000]],
    #index=['1','2','3'],
    columns=['city','total1','total2']
)

# %%
## 기본정보출력
## 판다스 자료구조
## 판다스 
data.info()
# 결측치는 없고 ,
# 데이터타입은 64비트 단위입니다. 
# 왜 혼자 city 가 오브젝트?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   city    4 non-null      object
#  1   total1  4 non-null      int64
#  2   total2  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
data.columns[0]
# Out:
# 'city'

# %%
data.dtypes
# dtype 이라는 attr 은 없다!
# Out:
# city      object
# total1     int64
# total2     int64
# dtype: object

# %%
## 컬럼 totlal1 오름차순 정렬 
data.sort_values('total1' )#  inplace: 'bool' = False, 가 있다! 
data.sort_values('total1' , inplace=True)
data
# Out:
#   city  total1  total2
# 0   서울   12000   15000
# 3   부산   42000   50000
# 2   제주   63000   66000
# 1   경기   75000   18000

# %%
## INDEX 기준으로 오름차순정렬
data.sort_index(         inplace=True)
data
# Out:
#   city  total1  total2
# 0   서울   12000   15000
# 1   경기   75000   18000
# 2   제주   63000   66000
# 3   부산   42000   50000

# %%
## 인덱스기준으로 내림차순 정렬> >원본적용하기 
data.sort_index(ascending=False,inplace=True)
data
## 내림차순 변경후에
##다시 순위 재부여를 또 하고싶으면??????????????
# Out:
#   city  total1  total2
# 3   부산   42000   50000
# 2   제주   63000   66000
# 1   경기   75000   18000
# 0   서울   12000   15000

# %%
##인덱스 재설정 해주기 
#ata.index
# 방법1 - 
data.reset_index() #나는 복사본! 
##어라, 3,2,1,0 도 처리에 포함되어버렸네.. 음.. 덮어쓰기 실패군. 
# 두번째줄 빼주려면어찌하는가
# Out:
#    index city  total1  total2
# 0      3   부산   42000   50000
# 1      2   제주   63000   66000
# 2      1   경기   75000   18000
# 3      0   서울   12000   15000

# %%
data# 아하 원본은 안 바뀌어 있구나 .
# Out:
#   city  total1  total2
# 3   부산   42000   50000
# 2   제주   63000   66000
# 1   경기   75000   18000
# 0   서울   12000   15000

# %%
## 2 ) 
data.reset_index(drop=True)
# 드 랍  파라미터가 있다! 기존 인덱스 안지울래! 라는  True 해주면,  
##data = data.reset_index(drop=True)
# Out:
#   city  total1  total2
# 0   부산   42000   50000
# 1   제주   63000   66000
# 2   경기   75000   18000
# 3   서울   12000   15000

# %%
##  3 기존인덱스삭제  새인덱스 설정 하고 원본에 적용 해버리기 
data.reset_index(drop=True,inplace=True)
data
##데이터 전처리작업때  리인덱싱은 흔히들 하게된다.
# Out:
#   city  total1  total2
# 0   부산   42000   50000
# 1   제주   63000   66000
# 2   경기   75000   18000
# 3   서울   12000   15000

# %%
data.city=='서울'
#마스크가 생기고
#그 마스크를 순회돌린다 
## 순회를 돌면서 비교를 해버린다.... 특정 컬럼에대한 조회이다. 

data.city.__dir__()
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__array_wrap__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
# ...

# %%
data.loc[data.city=='서울']#  data.city=='서울' 가 곧  [ F F F T ]  이기 때문 
data[data.city=='서울'] 
data[data['city']=='서울']
# Out:
#   city  total1  total2
# 3   서울   12000   15000

# %%
# city 에 산이 포함된 데이터 추출하기 

data['city'].str
data.city.str.contains('산')# 새로운 마스크를 추출
data = data[data['city'].str.contains('서')]# 새 마스크를 할당해버리기 = 즉 , 추출하기

# %%
data
# Out:
#   city  total1  total2
# 3   서울   12000   15000
